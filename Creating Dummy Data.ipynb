# %% [markdown]
# # [Problem 1] Creating random numbers

# %%
import numpy as np

mean = (-3,0) #The "mean" here is the normal distribution mean
cova = [[1.0, 0.8], #The "Cova" here is abbrivate for covariance
        [0.8, 1.0]]
np.random.seed(0)
random_ndarray = np.random.multivariate_normal(mean,cova,size=500)
print(random_ndarray)
print(random_ndarray.shape)
# Out:
# [[-4.80006782e+00 -1.54698618e+00]
#  [-4.63714503e+00 -2.19879728e-01]
#  [-4.46267867e+00 -2.08076347e+00]
#  [-3.85346966e+00 -9.49196365e-01]
#  [-3.03192065e+00  2.27764648e-01]
#  [-3.59653339e+00  3.23229932e-01]
#  [-3.76046080e+00 -6.83506760e-01]
#  [-3.52660272e+00 -3.15568548e-01]
#  [-4.35253112e+00 -1.48228460e+00]
#  [-3.02691331e+00 -5.67090887e-01]
#  [-7.84713550e-01  2.62867115e+00]
#  [-3.58538300e+00 -1.05476937e+00]
#  [-4.69336749e+00 -2.61318911e+00]
#  [-2.98421761e+00 -1.02603072e-01]
#  [-4.91877408e+00 -9.89469999e-01]
#  [-3.26658152e+00 -2.74105461e-02]
#  [-1.53138965e+00  2.15844669e-01]
#  [-2.71938344e+00  3.79500330e-01]
#  [-4.54738211e+00 -7.86930327e-01]
#  [-2.53695299e+00  2.71853959e-01]
#  [-1.55620621e+00  5.45695585e-01]
#  [-1.99817931e+00  2.23559938e+00]
#  [-2.37797023e+00  3.44967255e-01]
#  [-2.05735800e+00  1.43437007e+00]
#  [-1.40164768e+00  1.46380355e+00]
#  [-2.27283514e+00  9.71863483e-01]
#  [-2.14205902e+00  1.11243624e-01]
# ...

# %% [markdown]
# # [Problem 2] Visualization by scatter plot

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# %matplotlib inline

plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Scatter Plot")
plt.scatter(random_ndarray[:, 0], random_ndarray[:, 1], c='b', alpha=0.5)
plt.show()

# %% [markdown]
# # [Problem 3] Visualization by histogram

# %%
plt.xlabel("x1")
plt.ylabel("frequency")
plt.title("Histogram of x1")
plt.hist(random_ndarray[:, 0], color = 'r', bins=50)
plt.xlim(right = 3)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.xlabel("x2")
plt.ylabel("frequency")
plt.title("Histogram of x1")
plt.hist(random_ndarray[:, 1], bins=50)
plt.xlim(left = -3)
plt.show()

# %% [markdown]
# # [Problem 4] Addition of data

# %%
mean1 = (0, -3)
cova = [[1.0, 0.8],
       [0.8, 1.0]]
np.random.seed(0)
first_random_ndarray = np.random.multivariate_normal(mean1,cova,size=500)

plt.xlabel("x1")
plt.ylabel("y2")
plt.title("Scatter Plot")

plt.scatter(random_ndarray[:, 0], random_ndarray[:, 1], label="= 0")
plt.scatter(first_random_ndarray[:, 0], first_random_ndarray[:, 1], label="= 1")
plt.legend()
plt.show()

# %% [markdown]
# # [Problem 5] Data combination

# %%
np.random.seed(0)

combined_ndarray = np.concatenate((random_ndarray, first_random_ndarray))
print(combined_ndarray.shape)
print(combined_ndarray)
# Out:
# (1000, 2)
# [[-4.80006782 -1.54698618]
#  [-4.63714503 -0.21987973]
#  [-4.46267867 -2.08076347]
#  ...
#  [-0.40484501 -3.14372258]
#  [ 0.1584315  -2.78199606]
#  [ 1.20196495 -2.02452628]]

# %% [markdown]
# # [Problem 6] Labeling

# %%
first_ndarray = np.zeros((500, 1))
second_ndarray = np.ones((500, 1))

label = np.concatenate([first_ndarray, second_ndarray], axis=0)

labeled_ndarray = np.concatenate([combined_ndarray, label], axis = 1)
print(labeled_ndarray.shape)
print(labeled_ndarray)
# Out:
# (1000, 3)
# [[-4.80006782 -1.54698618  0.        ]
#  [-4.63714503 -0.21987973  0.        ]
#  [-4.46267867 -2.08076347  0.        ]
#  ...
#  [-0.40484501 -3.14372258  1.        ]
#  [ 0.1584315  -2.78199606  1.        ]
#  [ 1.20196495 -2.02452628  1.        ]]
